# %% [markdown]
# <a href="https://colab.research.google.com/github/raz0208/Data-Science-Practices/blob/main/ML_Clustering/DBSCAN_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DBSCAN Algorithm**
# ### **Density-Based Spatial Clustering of Applications with Noise**
# **DBSCAN** is a density-based clustering algorithm used in unsupervised machine learning to group together points that are closely packed (dense regions) and mark points that lie alone in low-density regions as outliers (noise).

# %% [markdown]
# ## **Step 1: Import required libraries**

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons, make_blobs

# %% [markdown]
# ## **Step 2: Generate random sample dataset**

# %%
# Generate sample data
# Option 1: Two interleaving half circles (moons)
X, _ = make_moons(n_samples=300, noise=0.1)
